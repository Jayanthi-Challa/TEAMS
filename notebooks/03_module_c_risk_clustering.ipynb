# %%
import pandas as pd
from src.clustering_model import identify_hotspots
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from src.clustering_model import identify_hotspots
#       4 poaching = pd.read_csv("../data/raw/poaching_incidents.csv")
#       5 clustered = identify_hotspots(poaching)
#
# ModuleNotFoundError: No module named 'src'

# %%
poaching = pd.read_csv("../data/raw/poaching_incidents.csv")
clustered = identify_hotspots(poaching)

# %%
clustered.head()
